# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data=pd.read_csv(r'C:\Users\User\Desktop\data science\DATA.csv')

# %%
data.head()
# Out:
#   1ST CHOICE 2ND CHOICE 3RD CHOICE 4TH CHOICE 5TH CHOICE 6TH CHOICE
# 0          A          B          D          C          F          E
# 1          A          C          B          D          F          E
# 2          B          C          A          D          F          E
# 3          A          B          C          D          F          E
# 4          A          C          B          D          F          E

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272 entries, 0 to 271
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   1ST CHOICE  272 non-null    object
#  1   2ND CHOICE  272 non-null    object
#  2   3RD CHOICE  272 non-null    object
#  3   4TH CHOICE  272 non-null    object
#  4   5TH CHOICE  272 non-null    object
#  5   6TH CHOICE  272 non-null    object
# dtypes: object(6)
# memory usage: 12.9+ KB

# %%
data.shape
# Out:
# (272, 6)

# %%
data['1ST CHOICE'].replace({'A':'Personal intrest','B':'Affordability','C':'Practicality','D':'Socio-economic-factor','E':'Social or external influence','F':'Parental discretion'},inplace=True)

# %%
data['2ND CHOICE'].replace({'A':'Personal intrest','B':'Affordability','C':'Practicality','D':'Socio-economic-factor','E':'Social or external influence','F':'Parental discretion'},inplace=True)

# %%
data['3RD CHOICE'].replace({'A':'Personal intrest','B':'Affordability','C':'Practicality','D':'Socio-economic-factor','E':'Social or external influence','F':'Parental discretion'},inplace=True)

# %%
data['4TH CHOICE'].replace({'A':'Personal intrest','B':'Affordability','C':'Practicality','D':'Socio-economic-factor','E':'Social or external influence','F':'Parental discretion'},inplace=True)

# %%
data['5TH CHOICE'].replace({'A':'Personal intrest','B':'Affordability','C':'Practicality','D':'Socio-economic-factor','E':'Social or external influence','F':'Parental discretion'},inplace=True)

# %%
data['6TH CHOICE'].replace({'A':'Personal intrest','B':'Affordability','C':'Practicality','D':'Socio-economic-factor','E':'Social or external influence','F':'Parental discretion'},inplace=True)

# %%
data.head()
# Out:
#          1ST CHOICE     2ND CHOICE             3RD CHOICE  \
# 0  Personal intrest  Affordability  Socio-economic-factor
# 1  Personal intrest   Practicality          Affordability
# 2     Affordability   Practicality       Personal intrest
# 3  Personal intrest  Affordability           Practicality
# 4  Personal intrest   Practicality          Affordability
#
#               4TH CHOICE           5TH CHOICE                    6TH CHOICE
# 0           Practicality  Parental discretion  Social or external influence
# 1  Socio-economic-factor  Parental discretion  Social or external influence
# 2  Socio-economic-factor  Parental discretion  Social or external influence
# 3  Socio-economic-factor  Parental discretion  Social or external influence
# 4  Socio-economic-factor  Parental discretion  Social or external influence

# %%
data['1ST CHOICE']
# Out:
# 0           Personal intrest
# 1           Personal intrest
# 2              Affordability
# 3           Personal intrest
# 4           Personal intrest
#                ...
# 267            Affordability
# 268            Affordability
# 269    Socio-economic-factor
# 270            Affordability
# 271            Affordability
# Name: 1ST CHOICE, Length: 272, dtype: object

# %%
sns.countplot(data['1ST CHOICE'])
fig=plt.gcf()
fig.set_size_inches(15,10)
plt.title('FIRST CHOICE',color='orange')
#plt.savefig('1ST BAR.png', dpi=300, bbox_inches='tight')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'FIRST CHOICE')

# %%
labels = ['Personal intrest','Affordability','Practicality','Socio-economic-factor','Social or external influence','Parental discretion']
values = data['1ST CHOICE'].value_counts().values

plt.style.use('fivethirtyeight')
plt.figure(figsize=(30, 20))

plt.subplot(1, 2, 2)
fig=plt.gcf()
plt.pie(values, labels=labels, autopct='%1.1f%%')
#plt.savefig('1ST.png', dpi=300, bbox_inches='tight')
# Out:
# ([<matplotlib.patches.Wedge at 0x1e13a348460>,
# ...
#  [Text(0.22704562305454054, 1.0763132838777822, 'Personal intrest'),
#   Text(-0.9789509837978165, -0.5016522414195788, 'Affordability'),
#   Text(0.31322889908746887, -1.0544608370046051, 'Practicality'),
#   Text(0.9284883115906029, -0.5898384992857212, 'Socio-economic-factor'),
#   Text(1.0646790807197977, -0.2765112205275703, 'Social or external influence'),
#   Text(1.0964067773031247, -0.08883793493646937, 'Parental discretion')],
#  [Text(0.12384306712065846, 0.5870799730242449, '43.4%'),
#   Text(-0.533973263889718, -0.27362849531977024, '28.3%'),
#   Text(0.170852126774983, -0.5751604565479663, '15.8%'),
#   Text(0.5064481699585106, -0.32173009051948426, '7.0%'),
#   Text(0.5807340440289805, -0.1508243021059474, '2.9%'),
#   Text(0.5980400603471588, -0.04845705541989238, '2.6%')])

# %%
sns.countplot(data['2ND CHOICE'])
fig=plt.gcf()
fig.set_size_inches(15,10)
plt.title('SECOND CHOICE',color='green')
#plt.savefig('2ND BAR.png', dpi=300, bbox_inches='tight')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'SECOND CHOICE')

# %%
labels = ['Personal intrest','Affordability','Practicality','Socio-economic-factor','Social or external influence','Parental discretion']
values = data['2ND CHOICE'].value_counts().values

plt.style.use('fivethirtyeight')
plt.figure(figsize=(15, 10))

plt.subplot(1, 2, 2)
fig=plt.gcf()
plt.pie(values, labels=labels, autopct='%1.1f%%')
#plt.savefig('2ND.png', dpi=300, bbox_inches='tight')

# %%
sns.countplot(data['3RD CHOICE'])
fig=plt.gcf()
fig.set_size_inches(15,10)
plt.title('The third Choice Of Student For Picking A Course ',color='blue')
#plt.savefig('3RD BAR.png', dpi=300, bbox_inches='tight')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'The third Choice Of Student For Picking A Course ')

# %%
label= ['Practicality',
'Affordability','Personal intrest','Socio-economic-factor','Social or external influence','Parental discretion']
val = data['3RD CHOICE'].value_counts().values

plt.style.use('fivethirtyeight')
plt.figure(figsize=(15, 10))

plt.subplot(1, 2, 2)
fig=plt.gcf()
plt.pie(val, labels=label, autopct='%1.1f%%')
#plt.savefig('3RD.png', dpi=300, bbox_inches='tight')
# Out:
# ([<matplotlib.patches.Wedge at 0x1e1411a7280>,
# ...
#  [Text(0.23946160385820425, 1.0736191784229903, 'Practicality'),
#   Text(-1.0302405119886504, -0.38549252581258114, 'Affordability'),
#   Text(0.10149518937727352, -1.0953075944835184, 'Personal intrest'),
#   Text(0.8214146865771972, -0.7316268944450341, 'Socio-economic-factor'),
#   Text(1.0429767149972737, -0.3495705536418874, 'Social or external influence'),
#   Text(1.0964067783428255, -0.0888379221048436, 'Parental discretion')],
#  [Text(0.13061542028629322, 0.5856104609579946, '43.0%'),
#   Text(-0.5619493701756274, -0.21026865044322604, '25.4%'),
#   Text(0.05536101238760373, -0.597440506081919, '16.2%'),
#   Text(0.44804437449665296, -0.39906921515183674, '7.7%'),
#   Text(0.5688963899985129, -0.19067484744102944, '5.1%'),
#   Text(0.5980400609142684, -0.04845704842082378, '2.6%')])

# %%
sns.countplot(data['4TH CHOICE'])
fig=plt.gcf()
fig.set_size_inches(15,10)
plt.title('The Fourth Choice Of Student For Picking A Course',color='green')
plt.savefig('4TH BAR.png', dpi=300, bbox_inches='tight')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
labels= ['Socio-economic-factor','Practicality',
'Affordability','Social or external influence','Parental discretion','Personal intrest']
var = data['4TH CHOICE'].value_counts().values

plt.style.use('fivethirtyeight')
plt.figure(figsize=(15, 10))

plt.subplot(1, 2, 2)
fig=plt.gcf()
plt.pie(var, labels=labels, autopct='%1.1f%%')
plt.savefig('4TH.png', dpi=300, bbox_inches='tight')

# %%
sns.countplot(data['5TH CHOICE'])
fig=plt.gcf()
fig.set_size_inches(15,10)
plt.title('The Fifth Choice Of Student For Picking A Course',color='green')
plt.savefig('5TH BAR.png', dpi=300, bbox_inches='tight')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
labels = ['Parental discretion','Social or external influence','Practicality','Affordability','Socio-economic-factor','Personal intrest']
values = data['5TH CHOICE'].value_counts().values

plt.style.use('fivethirtyeight')
plt.figure(figsize=(15, 10))

plt.subplot(1, 2, 2)
fig=plt.gcf()
plt.pie(values, labels=labels, autopct='%1.1f%%')
plt.savefig('5TH.png', dpi=300, bbox_inches='tight')

# %%
sns.countplot(data['6TH CHOICE'])
fig=plt.gcf()
fig.set_size_inches(15,10)
plt.title('The SIX Choice Of Student For Picking A Course',color='green')
#plt.savefig('6TH BAR.png', dpi=300, bbox_inches='tight')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'The SIX Choice Of Student For Picking A Course')

# %%
data['6TH CHOICE'].value_counts()
# Out:
# Social or external influence    181
# Parental discretion              67
# Socio-economic-factor            12
# Practicality                      7
# Affordability                     5
# Name: 6TH CHOICE, dtype: int64

# %%
labels = ['Social or external influence','Parental discretion','Socio-economic-factor','Practicality','Affordability']
values = data['6TH CHOICE'].value_counts().values

plt.style.use('fivethirtyeight')
plt.figure(figsize=(15, 10))

plt.subplot(1, 2, 2)
fig=plt.gcf()
plt.pie(values, labels=labels, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1db8d364280>,
# ...
#  [Text(-0.5463282607903506, 0.9547384099646304, 'Social or external influence'),
#   Text(0.2641958804783815, -1.0678017310054582, 'Parental discretion'),
#   Text(1.0062731883492282, -0.44431325707149344, 'Socio-economic-factor'),
#   Text(1.0788637770494145, -0.21459951204667643, 'Practicality'),
#   Text(1.0981662248605248, -0.06348970448492612, 'Affordability')],
#  [Text(-0.297997233158373, 0.5207664054352529, '66.5%'),
#   Text(0.144106843897299, -0.582437307821159, '24.6%'),
#   Text(0.5488762845541244, -0.24235268567536, '4.4%'),
#   Text(0.5884711511178623, -0.11705427929818712, '2.6%'),
#   Text(0.5989997590148317, -0.034630747900868786, '1.8%')])

# %% [markdown]
# #  Data Visualization

# %%
col=data.columns

# %%
# univariate analysis of categorical data:
sns.set(rc={"axes.facecolor":"white","figure.facecolor":"#9ed9cd"})
sns.set_palette("pastel")
for i, col in enumerate(col):

    fig, axes = plt.subplots(1,2,figsize=(10,5))

    # count of col (countplot)
    
    ax=sns.countplot(data=data, x=col, ax=axes[0])
    activities = [var for var in data[col].value_counts().sort_index().index]
    ax.set_xticklabels(activities,rotation=90)
    for container in axes[0].containers:
        axes[0].bar_label(container)
        
    #count of col (pie chart)
    
    index = data[col].value_counts().index
    size = data[col].value_counts().values
    explode = (0.05, 0.05)

    axes[1].pie(size, labels=index,autopct='%1.1f%%', pctdistance=0.85)

    # Inner circle
    centre_circle = plt.Circle((0,0),0.70,fc='white')
    fig = plt.gcf()
    fig.gca().add_artist(centre_circle)
    plt.suptitle(col,backgroundcolor='black',color='white',fontsize=15)

    plt.show()
